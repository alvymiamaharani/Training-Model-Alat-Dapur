# %% [markdown]
# # Set Up YOLOv5

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-228-g4d687c8 Python-3.10.12 torch-2.1.0+cu118 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.1/107.7 GB disk)

# %% [markdown]
# # Upload Custom Model
#
#
# ---
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Ekstrak File Custom Model .zip

# %%
# !unzip "/content/sikat.zip"
# Out:
# Archive:  /content/sikat.zip
#    creating: sikat/
#    creating: sikat/test/
#    creating: sikat/test/images/
#   inflating: sikat/test/images/sikat-10_jpg.rf.d58206d475c67cd0c522481ae9b58c9a.jpg
#   inflating: sikat/test/images/sikat-12_jpg.rf.3857e3b29a9afb988ed8a568fff0baca.jpg
#    creating: sikat/test/labels/
#   inflating: sikat/test/labels/sikat-10_jpg.rf.d58206d475c67cd0c522481ae9b58c9a.txt
#   inflating: sikat/test/labels/sikat-12_jpg.rf.3857e3b29a9afb988ed8a568fff0baca.txt
#    creating: sikat/train/
#    creating: sikat/train/images/
#   inflating: sikat/train/images/sikat-13_jpg.rf.1b30895f9e1a212701598684772e933e.jpg
#   inflating: sikat/train/images/sikat-13_jpg.rf.8f453ab0695abfedf9857cac2b133eba.jpg
#   inflating: sikat/train/images/sikat-13_jpg.rf.f5e6c609b365692f27a469b802c19668.jpg
#   inflating: sikat/train/images/sikat-14_jpg.rf.069aa4f2a6cd61c2bc2c33746d7c1d65.jpg
#   inflating: sikat/train/images/sikat-14_jpg.rf.6f9947c771fe095017021927aee6a2e6.jpg
# ...

# %% [markdown]
# # Set Up Custom Training Data .yaml
#
#
#
# ---
#
# ```
# path: ../yolov5/sikat  # dataset root dir
# train: train/images
# val: valid/images
# test: test/images
#
# # Classes
# names:
#   0: sikat
#
# roboflow:
#   workspace: alvy-mia-maharani
#   project: sikat-finder
#   version: 1
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/alvy-mia-maharani/sikat-finder/dataset/1
#
# ```
#
# ### Upload File ke Folder :  `yolov5/data` dengan nama `sikat.yaml`

# %% [markdown]
# # Train Custom Model
#
# Menggunakan file `sikat.yaml`
#
# Menggunakan epoch sebanyak 100

# %%
# !python train.py --img 640 --batch 16 --epochs 100 --data sikat.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=sikat.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-228-g4d687c8 Python-3.10.12 torch-2.1.0+cu118 CPU
#
# ...

# %% [markdown]
# # Menyimpan File Weights Hasil Train
#
#
# ---
#
#
# ![image.png](data:image/png;base64,...)
#
# ---
#
# ![image.png](data:image/png;base64,...)
